# %%
# !pip install agentpy
# Out:
# Requirement already satisfied: agentpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.1.5)
# Requirement already satisfied: numpy>=1.19 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from agentpy) (2.2.6)
# Requirement already satisfied: scipy>=1.5.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from agentpy) (1.15.3)
# Requirement already satisfied: matplotlib>=3.3.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from agentpy) (3.10.3)
# Requirement already satisfied: networkx>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from agentpy) (3.5)
# Requirement already satisfied: pandas>=1.1.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from agentpy) (2.3.0)
# Requirement already satisfied: SALib>=1.3.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from agentpy) (1.5.1)
# Requirement already satisfied: joblib>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from agentpy) (1.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.3->agentpy) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.3->agentpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.3->agentpy) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.3->agentpy) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/cruh/Library/Python/3.13/lib/python/site-packages (from matplotlib>=3.3.3->agentpy) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.3->agentpy) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib>=3.3.3->agentpy) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/cruh/Library/Python/3.13/lib/python/site-packages (from matplotlib>=3.3.3->agentpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.1.3->agentpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas>=1.1.3->agentpy) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/cruh/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.3->agentpy) (1.17.0)
# Requirement already satisfied: multiprocess in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from SALib>=1.3.7->agentpy) (0.70.18)
# Requirement already satisfied: dill>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from multiprocess->SALib>=1.3.7->agentpy) (0.4.0)

# %%
import agentpy as ap
import numpy as np
import socket
import json
import time

class CircularAgent(ap.Agent):
    def setup(self):
        self.radius = self.p.radius
        self.speed = self.p.speed
        self.angle = 2 * np.pi * self.id / self.p.n
        self.x = self.radius * np.cos(self.angle)
        self.y = self.radius * np.sin(self.angle)
        print(f"Agent {self.id} initialized at position ({self.x:.2f}, {self.y:.2f})")

    def move(self):
        self.angle += self.speed
        self.x = self.radius * np.cos(self.angle)
        self.y = self.radius * np.sin(self.angle)
        
        data = {
            "id": f"agent_{self.id}",
            "position": {
                "x": float(self.x),
                "y": float(self.y)
            }
        }
        
        self.send_to_unity(data)
    
    def send_to_unity(self, data):
        message = json.dumps(data).encode('utf-8')
        MAX_RETRIES = 3
        
        for attempt in range(MAX_RETRIES):
            try:
                with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
                    s.settimeout(5) 
                    s.connect(("127.0.0.1", 1114))
                    
                    initial_message = s.recv(1024)
                    print(f"Agent {self.id} received: {initial_message.decode('utf-8')}")
                    
                    s.sendall(message + b"$")
                    print(f"Agent {self.id} sent position: ({self.x:.2f}, {self.y:.2f})")
                    break 
                    
            except ConnectionRefusedError:
                print(f"Agent {self.id} attempt {attempt+1}: Unity server not running")
                if attempt == MAX_RETRIES - 1:
                    print(f"Agent {self.id}: Failed to connect after {MAX_RETRIES} attempts")
                else:
                    time.sleep(1)  
            except socket.timeout:
                print(f"Agent {self.id} attempt {attempt+1}: Connection timeout")
                if attempt < MAX_RETRIES - 1:
                    time.sleep(0.5)
            except Exception as e:
                print(f"Agent {self.id} attempt {attempt+1} failed: {e}")
                if attempt < MAX_RETRIES - 1:
                    time.sleep(0.5)

class CircleModel(ap.Model):
    def setup(self):
        print(f"Setting up model with {self.p.n} agents")
        self.agents = ap.AgentList(self, self.p.n, CircularAgent)
        print("Model setup complete")

    def step(self):
        print(f"Step {self.t}: Moving agents")
        for agent in self.agents:
            agent.move()
            time.sleep(self.p.agent_delay)  
        print(f"Step {self.t} complete")


parameters = {
    'n': 7,                
    'radius': 4.0,         
    'speed': 0.25,         
    'steps': 200,          
    'agent_delay': 0.2     
}

print("Starting circular agent simulation...")
print(f"Parameters: {parameters}")
print("Make sure Unity is running with the TCPIPServerAsync script!")
print("-" * 50)


model = CircleModel(parameters)
results = model.run()

print("-" * 50)
print("Simulation complete!")
# Out:
# Starting circular agent simulation...
# Parameters: {'n': 7, 'radius': 4.0, 'speed': 0.25, 'steps': 200, 'agent_delay': 0.2}
# Make sure Unity is running with the TCPIPServerAsync script!
# --------------------------------------------------
# Setting up model with 7 agents
# Agent 1 initialized at position (2.49, 3.13)
# Agent 2 initialized at position (-0.89, 3.90)
# Agent 3 initialized at position (-3.60, 1.74)
# Agent 4 initialized at position (-3.60, -1.74)
# Agent 5 initialized at position (-0.89, -3.90)
# Agent 6 initialized at position (2.49, -3.13)
# Agent 7 initialized at position (4.00, -0.00)
# Model setup complete
# Step 1: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (1.64, 3.65)
# Agent 2 received: I will send key
# Agent 2 sent position: (-1.83, 3.56)
# Agent 3 received: I will send key
# Agent 3 sent position: (-3.92, 0.79)
# Agent 4 received: I will send key
# Agent 4 sent position: (-3.06, -2.57)
# Agent 5 received: I will send key
# Agent 5 sent position: (0.10, -4.00)
# Agent 6 received: I will send key
# Agent 6 sent position: (3.19, -2.41)
# Agent 7 received: I will send key
# Agent 7 sent position: (3.88, 0.99)
# Step 1 complete
# Completed: 1 stepsStep 2: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (0.69, 3.94)
# Agent 2 received: I will send key
# Agent 2 sent position: (-2.65, 3.00)
# Agent 3 received: I will send key
# Agent 3 sent position: (-3.99, -0.20)
# Agent 4 received: I will send key
# Agent 4 sent position: (-2.33, -3.25)
# Agent 5 received: I will send key
# Agent 5 sent position: (1.09, -3.85)
# Agent 6 received: I will send key
# Agent 6 sent position: (3.69, -1.55)
# Agent 7 received: I will send key
# Agent 7 sent position: (3.51, 1.92)
# Step 2 complete
# Completed: 2 stepsStep 3: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-0.31, 3.99)
# Agent 2 received: I will send key
# Agent 2 sent position: (-3.31, 2.25)
# Agent 3 received: I will send key
# Agent 3 sent position: (-3.82, -1.19)
# Agent 4 received: I will send key
# Agent 4 sent position: (-1.45, -3.73)
# Agent 5 received: I will send key
# Agent 5 sent position: (2.01, -3.46)
# Agent 6 received: I will send key
# Agent 6 sent position: (3.96, -0.59)
# Agent 7 received: I will send key
# Agent 7 sent position: (2.93, 2.73)
# Step 3 complete
# Completed: 3 stepsStep 4: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-1.28, 3.79)
# Agent 2 received: I will send key
# Agent 2 sent position: (-3.76, 1.36)
# Agent 3 received: I will send key
# Agent 3 sent position: (-3.41, -2.09)
# Agent 4 received: I will send key
# Agent 4 sent position: (-0.49, -3.97)
# Agent 5 received: I will send key
# Agent 5 sent position: (2.80, -2.86)
# Agent 6 received: I will send key
# Agent 6 sent position: (3.98, 0.41)
# Agent 7 received: I will send key
# Agent 7 sent position: (2.16, 3.37)
# Step 4 complete
# Completed: 4 stepsStep 5: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-2.18, 3.35)
# Agent 2 received: I will send key
# Agent 2 sent position: (-3.98, 0.38)
# Agent 3 received: I will send key
# Agent 3 sent position: (-2.78, -2.87)
# Agent 4 received: I will send key
# Agent 4 sent position: (0.51, -3.97)
# Agent 5 received: I will send key
# Agent 5 sent position: (3.42, -2.07)
# Agent 6 received: I will send key
# Agent 6 sent position: (3.75, 1.38)
# Agent 7 received: I will send key
# Agent 7 sent position: (1.26, 3.80)
# Step 5 complete
# Completed: 5 stepsStep 6: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-2.94, 2.71)
# Agent 2 received: I will send key
# Agent 2 sent position: (-3.95, -0.61)
# Agent 3 received: I will send key
# Agent 3 sent position: (-1.99, -3.47)
# Agent 4 received: I will send key
# Agent 4 sent position: (1.48, -3.72)
# Agent 5 received: I will send key
# Agent 5 sent position: (3.83, -1.16)
# Agent 6 received: I will send key
# Agent 6 sent position: (3.30, 2.27)
# Agent 7 received: I will send key
# Agent 7 sent position: (0.28, 3.99)
# Step 6 complete
# Completed: 6 stepsStep 7: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-3.52, 1.90)
# Agent 2 received: I will send key
# Agent 2 sent position: (-3.68, -1.57)
# Agent 3 received: I will send key
# Agent 3 sent position: (-1.07, -3.86)
# Agent 4 received: I will send key
# Agent 4 sent position: (2.35, -3.24)
# Agent 5 received: I will send key
# Agent 5 sent position: (4.00, -0.18)
# Agent 6 received: I will send key
# Agent 6 sent position: (2.63, 3.01)
# Agent 7 received: I will send key
# Agent 7 sent position: (-0.71, 3.94)
# Step 7 complete
# Completed: 7 stepsStep 8: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-3.88, 0.97)
# Agent 2 received: I will send key
# Agent 2 sent position: (-3.18, -2.43)
# Agent 3 received: I will send key
# Agent 3 sent position: (-0.08, -4.00)
# Agent 4 received: I will send key
# Agent 4 sent position: (3.08, -2.55)
# Agent 5 received: I will send key
# Agent 5 sent position: (3.92, 0.81)
# Agent 6 received: I will send key
# Agent 6 sent position: (1.81, 3.57)
# Agent 7 received: I will send key
# Agent 7 sent position: (-1.66, 3.64)
# Step 8 complete
# Completed: 8 stepsStep 9: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-4.00, -0.02)
# Agent 2 received: I will send key
# Agent 2 sent position: (-2.48, -3.14)
# Agent 3 received: I will send key
# Agent 3 sent position: (0.91, -3.89)
# Agent 4 received: I will send key
# Agent 4 sent position: (3.61, -1.71)
# Agent 5 received: I will send key
# Agent 5 sent position: (3.59, 1.76)
# Agent 6 received: I will send key
# Agent 6 sent position: (0.87, 3.90)
# Agent 7 received: I will send key
# Agent 7 sent position: (-2.51, 3.11)
# Step 9 complete
# Completed: 9 stepsStep 10: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-3.87, -1.01)
# Agent 2 received: I will send key
# Agent 2 sent position: (-1.62, -3.66)
# Agent 3 received: I will send key
# Agent 3 sent position: (1.85, -3.55)
# Agent 4 received: I will send key
# Agent 4 sent position: (3.93, -0.77)
# Agent 5 received: I will send key
# Agent 5 sent position: (3.05, 2.59)
# Agent 6 received: I will send key
# Agent 6 sent position: (-0.13, 4.00)
# Agent 7 received: I will send key
# Agent 7 sent position: (-3.20, 2.39)
# Step 10 complete
# Completed: 10 stepsStep 11: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-3.50, -1.94)
# Agent 2 received: I will send key
# Agent 2 sent position: (-0.67, -3.94)
# Agent 3 received: I will send key
# Agent 3 sent position: (2.67, -2.98)
# Agent 4 received: I will send key
# Agent 4 sent position: (3.99, 0.23)
# Agent 5 received: I will send key
# Agent 5 sent position: (2.31, 3.26)
# Agent 6 received: I will send key
# Agent 6 sent position: (-1.11, 3.84)
# Agent 7 received: I will send key
# Agent 7 sent position: (-3.70, 1.53)
# Step 11 complete
# Completed: 11 stepsStep 12: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-2.91, -2.74)
# Agent 2 received: I will send key
# Agent 2 sent position: (0.33, -3.99)
# Agent 3 received: I will send key
# Agent 3 sent position: (3.32, -2.23)
# Agent 4 received: I will send key
# Agent 4 sent position: (3.81, 1.21)
# Agent 5 received: I will send key
# Agent 5 sent position: (1.43, 3.74)
# Agent 6 received: I will send key
# Agent 6 sent position: (-2.03, 3.45)
# Agent 7 received: I will send key
# Agent 7 sent position: (-3.96, 0.56)
# Step 12 complete
# Completed: 12 stepsStep 13: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-2.14, -3.38)
# Agent 2 received: I will send key
# Agent 2 sent position: (1.31, -3.78)
# Agent 3 received: I will send key
# Agent 3 sent position: (3.77, -1.34)
# Agent 4 received: I will send key
# Agent 4 sent position: (3.39, 2.12)
# Agent 5 received: I will send key
# Agent 5 sent position: (0.46, 3.97)
# Agent 6 received: I will send key
# Agent 6 sent position: (-2.82, 2.84)
# Agent 7 received: I will send key
# Agent 7 sent position: (-3.98, -0.43)
# Step 13 complete
# Completed: 13 stepsStep 14: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-1.24, -3.80)
# Agent 2 received: I will send key
# Agent 2 sent position: (2.20, -3.34)
# Agent 3 received: I will send key
# Agent 3 sent position: (3.98, -0.36)
# Agent 4 received: I will send key
# Agent 4 sent position: (2.77, 2.89)
# Agent 5 received: I will send key
# Agent 5 sent position: (-0.53, 3.96)
# Agent 6 received: I will send key
# Agent 6 sent position: (-3.43, 2.05)
# Agent 7 received: I will send key
# Agent 7 sent position: (-3.75, -1.40)
# Step 14 complete
# Completed: 14 stepsStep 15: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-0.26, -3.99)
# Agent 2 received: I will send key
# Agent 2 sent position: (2.96, -2.69)
# Agent 3 received: I will send key
# Agent 3 sent position: (3.95, 0.64)
# Agent 4 received: I will send key
# Agent 4 sent position: (1.97, 3.48)
# Agent 5 received: I will send key
# Agent 5 sent position: (-1.50, 3.71)
# Agent 6 received: I will send key
# Agent 6 sent position: (-3.83, 1.14)
# Agent 7 received: I will send key
# Agent 7 sent position: (-3.28, -2.29)
# Step 15 complete
# Completed: 15 stepsStep 16: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (0.74, -3.93)
# Agent 2 received: I will send key
# Agent 2 sent position: (3.53, -1.88)
# Agent 3 received: I will send key
# Agent 3 sent position: (3.67, 1.59)
# Agent 4 received: I will send key
# Agent 4 sent position: (1.04, 3.86)
# Agent 5 received: I will send key
# Agent 5 sent position: (-2.37, 3.22)
# Agent 6 received: I will send key
# Agent 6 sent position: (-4.00, 0.16)
# Agent 7 received: I will send key
# Agent 7 sent position: (-2.61, -3.03)
# Step 16 complete
# Completed: 16 stepsStep 17: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (1.69, -3.63)
# Agent 2 received: I will send key
# Agent 2 sent position: (3.89, -0.94)
# Agent 3 received: I will send key
# Agent 3 sent position: (3.16, 2.45)
# Agent 4 received: I will send key
# Agent 4 sent position: (0.05, 4.00)
# Agent 5 received: I will send key
# Agent 5 sent position: (-3.09, 2.54)
# Agent 6 received: I will send key
# Agent 6 sent position: (-3.91, -0.84)
# Agent 7 received: I will send key
# Agent 7 sent position: (-1.78, -3.58)
# Step 17 complete
# Completed: 17 stepsStep 18: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (2.53, -3.10)
# Agent 2 received: I will send key
# Agent 2 sent position: (4.00, 0.05)
# Agent 3 received: I will send key
# Agent 3 sent position: (2.46, 3.16)
# Agent 4 received: I will send key
# Agent 4 sent position: (-0.94, 3.89)
# Agent 5 received: I will send key
# Agent 5 sent position: (-3.62, 1.69)
# Agent 6 received: I will send key
# Agent 6 sent position: (-3.58, -1.78)
# Agent 7 received: I will send key
# Agent 7 sent position: (-0.84, -3.91)
# Step 18 complete
# Completed: 18 stepsStep 19: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (3.22, -2.37)
# Agent 2 received: I will send key
# Agent 2 sent position: (3.86, 1.04)
# Agent 3 received: I will send key
# Agent 3 sent position: (1.60, 3.67)
# Agent 4 received: I will send key
# Agent 4 sent position: (-1.87, 3.54)
# Agent 5 received: I will send key
# Agent 5 sent position: (-3.93, 0.74)
# Agent 6 received: I will send key
# Agent 6 sent position: (-3.03, -2.61)
# Agent 7 received: I will send key
# Agent 7 sent position: (0.15, -4.00)
# Step 19 complete
# Completed: 19 stepsStep 20: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (3.71, -1.50)
# Agent 2 received: I will send key
# Agent 2 sent position: (3.49, 1.96)
# Agent 3 received: I will send key
# Agent 3 sent position: (0.64, 3.95)
# Agent 4 received: I will send key
# Agent 4 sent position: (-2.69, 2.96)
# Agent 5 received: I will send key
# Agent 5 sent position: (-3.99, -0.25)
# Agent 6 received: I will send key
# Agent 6 sent position: (-2.29, -3.28)
# Agent 7 received: I will send key
# Agent 7 sent position: (1.13, -3.84)
# Step 20 complete
# Completed: 20 stepsStep 21: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (3.96, -0.54)
# Agent 2 received: I will send key
# Agent 2 sent position: (2.89, 2.76)
# Agent 3 received: I will send key
# Agent 3 sent position: (-0.35, 3.98)
# Agent 4 received: I will send key
# Agent 4 sent position: (-3.34, 2.21)
# Agent 5 received: I will send key
# Agent 5 sent position: (-3.81, -1.23)
# Agent 6 received: I will send key
# Agent 6 sent position: (-1.41, -3.74)
# Agent 7 received: I will send key
# Agent 7 sent position: (2.05, -3.44)
# Step 21 complete
# Completed: 21 stepsStep 22: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (3.97, 0.46)
# Agent 2 received: I will send key
# Agent 2 sent position: (2.12, 3.39)
# Agent 3 received: I will send key
# Agent 3 sent position: (-1.33, 3.77)
# Agent 4 received: I will send key
# Agent 4 sent position: (-3.78, 1.31)
# Agent 5 received: I will send key
# Agent 5 sent position: (-3.38, -2.14)
# Agent 6 received: I will send key
# Agent 6 sent position: (-0.44, -3.98)
# Agent 7 received: I will send key
# Agent 7 sent position: (2.83, -2.82)
# Step 22 complete
# Completed: 22 stepsStep 23: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (3.74, 1.43)
# Agent 2 received: I will send key
# Agent 2 sent position: (1.22, 3.81)
# Agent 3 received: I will send key
# Agent 3 sent position: (-2.22, 3.33)
# Agent 4 received: I will send key
# Agent 4 sent position: (-3.99, 0.34)
# Agent 5 received: I will send key
# Agent 5 sent position: (-2.75, -2.91)
# Agent 6 received: I will send key
# Agent 6 sent position: (0.56, -3.96)
# Agent 7 received: I will send key
# Agent 7 sent position: (3.44, -2.03)
# Step 23 complete
# Completed: 23 stepsStep 24: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (3.27, 2.31)
# Agent 2 received: I will send key
# Agent 2 sent position: (0.24, 3.99)
# Agent 3 received: I will send key
# Agent 3 sent position: (-2.98, 2.67)
# Agent 4 received: I will send key
# Agent 4 sent position: (-3.95, -0.66)
# Agent 5 received: I will send key
# Agent 5 sent position: (-1.94, -3.50)
# Agent 6 received: I will send key
# Agent 6 sent position: (1.52, -3.70)
# Agent 7 received: I will send key
# Agent 7 sent position: (3.84, -1.12)
# Step 24 complete
# Completed: 24 stepsStep 25: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (2.60, 3.04)
# Agent 2 received: I will send key
# Agent 2 sent position: (-0.76, 3.93)
# Agent 3 received: I will send key
# Agent 3 sent position: (-3.54, 1.85)
# Agent 4 received: I will send key
# Agent 4 sent position: (-3.66, -1.62)
# Agent 5 received: I will send key
# Agent 5 sent position: (-1.02, -3.87)
# Agent 6 received: I will send key
# Agent 6 sent position: (2.39, -3.21)
# Agent 7 received: I will send key
# Agent 7 sent position: (4.00, -0.13)
# Step 25 complete
# Completed: 25 stepsStep 26: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (1.76, 3.59)
# Agent 2 received: I will send key
# Agent 2 sent position: (-1.71, 3.62)
# Agent 3 received: I will send key
# Agent 3 sent position: (-3.89, 0.92)
# Agent 4 received: I will send key
# Agent 4 sent position: (-3.15, -2.47)
# Agent 5 received: I will send key
# Agent 5 sent position: (-0.03, -4.00)
# Agent 6 received: I will send key
# Agent 6 sent position: (3.11, -2.52)
# Agent 7 received: I will send key
# Agent 7 sent position: (3.91, 0.86)
# Step 26 complete
# Completed: 26 stepsStep 27: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (0.82, 3.92)
# Agent 2 received: I will send key
# Agent 2 sent position: (-2.55, 3.08)
# Agent 3 received: I will send key
# Agent 3 sent position: (-4.00, -0.07)
# Agent 4 received: I will send key
# Agent 4 sent position: (-2.44, -3.17)
# Agent 5 received: I will send key
# Agent 5 sent position: (0.96, -3.88)
# Agent 6 received: I will send key
# Agent 6 sent position: (3.63, -1.67)
# Agent 7 received: I will send key
# Agent 7 sent position: (3.57, 1.80)
# Step 27 complete
# Completed: 27 stepsStep 28: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-0.17, 4.00)
# Agent 2 received: I will send key
# Agent 2 sent position: (-3.23, 2.36)
# Agent 3 received: I will send key
# Agent 3 sent position: (-3.86, -1.06)
# Agent 4 received: I will send key
# Agent 4 sent position: (-1.58, -3.68)
# Agent 5 received: I will send key
# Agent 5 sent position: (1.89, -3.52)
# Agent 6 received: I will send key
# Agent 6 sent position: (3.93, -0.72)
# Agent 7 received: I will send key
# Agent 7 sent position: (3.02, 2.63)
# Step 28 complete
# Completed: 28 stepsStep 29: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-1.16, 3.83)
# Agent 2 received: I will send key
# Agent 2 sent position: (-3.72, 1.48)
# Agent 3 received: I will send key
# Agent 3 sent position: (-3.48, -1.98)
# Agent 4 received: I will send key
# Agent 4 sent position: (-0.62, -3.95)
# Agent 5 received: I will send key
# Agent 5 sent position: (2.70, -2.95)
# Agent 6 received: I will send key
# Agent 6 sent position: (3.99, 0.28)
# Agent 7 received: I will send key
# Agent 7 sent position: (2.27, 3.29)
# Step 29 complete
# Completed: 29 stepsStep 30: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-2.07, 3.42)
# Agent 2 received: I will send key
# Agent 2 sent position: (-3.97, 0.52)
# Agent 3 received: I will send key
# Agent 3 sent position: (-2.88, -2.78)
# Agent 4 received: I will send key
# Agent 4 sent position: (0.38, -3.98)
# Agent 5 received: I will send key
# Agent 5 sent position: (3.35, -2.19)
# Agent 6 received: I will send key
# Agent 6 sent position: (3.80, 1.26)
# Agent 7 received: I will send key
# Agent 7 sent position: (1.39, 3.75)
# Step 30 complete
# Completed: 30 stepsStep 31: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-2.85, 2.81)
# Agent 2 received: I will send key
# Agent 2 sent position: (-3.97, -0.48)
# Agent 3 received: I will send key
# Agent 3 sent position: (-2.10, -3.40)
# Agent 4 received: I will send key
# Agent 4 sent position: (1.35, -3.76)
# Agent 5 received: I will send key
# Agent 5 sent position: (3.79, -1.29)
# Agent 6 received: I will send key
# Agent 6 sent position: (3.37, 2.16)
# Agent 7 received: I will send key
# Agent 7 sent position: (0.42, 3.98)
# Step 31 complete
# Completed: 31 stepsStep 32: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-3.46, 2.01)
# Agent 2 received: I will send key
# Agent 2 sent position: (-3.73, -1.45)
# Agent 3 received: I will send key
# Agent 3 sent position: (-1.19, -3.82)
# Agent 4 received: I will send key
# Agent 4 sent position: (2.24, -3.31)
# Agent 5 received: I will send key
# Agent 5 sent position: (3.99, -0.31)
# Agent 6 received: I will send key
# Agent 6 sent position: (2.73, 2.92)
# Agent 7 received: I will send key
# Agent 7 sent position: (-0.58, 3.96)
# Step 32 complete
# Completed: 32 stepsStep 33: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-3.85, 1.09)
# Agent 2 received: I will send key
# Agent 2 sent position: (-3.25, -2.33)
# Agent 3 received: I will send key
# Agent 3 sent position: (-0.21, -3.99)
# Agent 4 received: I will send key
# Agent 4 sent position: (2.99, -2.66)
# Agent 5 received: I will send key
# Agent 5 sent position: (3.94, 0.68)
# Agent 6 received: I will send key
# Agent 6 sent position: (1.92, 3.51)
# Agent 7 received: I will send key
# Agent 7 sent position: (-1.54, 3.69)
# Step 33 complete
# Completed: 33 stepsStep 34: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-4.00, 0.11)
# Agent 2 received: I will send key
# Agent 2 sent position: (-2.58, -3.06)
# Agent 3 received: I will send key
# Agent 3 sent position: (0.78, -3.92)
# Agent 4 received: I will send key
# Agent 4 sent position: (3.56, -1.83)
# Agent 5 received: I will send key
# Agent 5 sent position: (3.65, 1.64)
# Agent 6 received: I will send key
# Agent 6 sent position: (1.00, 3.87)
# Agent 7 received: I will send key
# Agent 7 sent position: (-2.41, 3.19)
# Step 34 complete
# Completed: 34 stepsStep 35: Moving agents
# Agent 1 received: I will send key
# Agent 1 sent position: (-3.90, -0.88)
# Agent 2 received: I will send key
# Agent 2 sent position: (-1.74, -3.60)
# Agent 3 received: I will send key
# Agent 3 sent position: (1.73, -3.61)
# Agent 4 received: I will send key
# Agent 4 sent position: (3.90, -0.90)
# Agent 5 attempt 1: Connection timeout
# Agent 5 attempt 2: Connection timeout
# Agent 5 attempt 3: Connection timeout
# Agent 6 attempt 1: Connection timeout
# Agent 6 attempt 2: Connection timeout
# Agent 6 attempt 3: Connection timeout
# Agent 7 attempt 1: Connection timeout
# Agent 7 attempt 2: Connection timeout
# Agent 7 attempt 3: Connection timeout
# Step 35 complete
# Completed: 35 stepsStep 36: Moving agents
# Agent 1 attempt 1: Connection timeout
# Agent 1 attempt 2: Connection timeout
# Agent 1 attempt 3: Connection timeout
# Agent 2 attempt 1: Connection timeout
# Agent 2 attempt 2: Connection timeout
# Agent 2 attempt 3: Connection timeout
# Agent 3 attempt 1: Connection timeout
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 92
#      88 print("-" * 50)
#      91 model = CircleModel(parameters)
# ---> 92 results = model.run()
#      94 print("-" * 50)
#      95 print("Simulation complete!")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agentpy/model.py:378, in Model.run(self, steps, seed, display)
#     376 self.sim_setup(steps, seed)
#     377 while self.running:
# --> 378     self.sim_step()
#     379     if display:
#     380         print(f"\rCompleted: {self.t} steps", end='')
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/agentpy/model.py:327, in Model.sim_step(self)
#     324 """ Proceeds the simulation by one step, incrementing `Model.t` by 1
#     325 and then calling :func:`Model.step` and :func:`Model.update`."""
#     326 self.t += 1
# --> 327 self.step()
#     328 self.update()
#     329 if self.t >= self._steps:
#
# Cell In[4], line 72, in CircleModel.step(self)
#      70 print(f"Step {self.t}: Moving agents")
#      71 for agent in self.agents:
# ---> 72     agent.move()
#      73     time.sleep(self.p.agent_delay)
#      74 print(f"Step {self.t} complete")
#
# Cell In[4], line 29, in CircularAgent.move(self)
#      19 self.y = self.radius * np.sin(self.angle)
#      21 data = {
#      22     "id": f"agent_{self.id}",
#      23     "position": {
#    (...)     26     }
#      27 }
# ---> 29 self.send_to_unity(data)
#
# Cell In[4], line 39, in CircularAgent.send_to_unity(self, data)
#      37 with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
#      38     s.settimeout(5)
# ---> 39     s.connect(("127.0.0.1", 1114))
#      41     initial_message = s.recv(1024)
#      42     print(f"Agent {self.id} received: {initial_message.decode('utf-8')}")
#
# KeyboardInterrupt:
